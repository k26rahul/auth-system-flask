# %%
student1 = {
    "name": "vidu",
    "mood": "happy",
    "state": "sleeping",
    "address": {
        "state": "ka",
        "city": "hbh"
    }
}

student2 = dict(
    name="vidu",
    mood="happy",
    state="sleeping",
    salary=999
)

# %%
student1.get("name")
student2.get("state")
# Out:
# 'vidu'
# 'sleeping'

# %%
print(student2.get("salary", 250))
# Out:
# 999

# %%
import string
import secrets

secrets.choice("apple")
secrets.choice([10, 20, 30])
# Out:
# 'e'
# 10

# %%
for elem in set([99, 92, 92]):
  elem
# Out:
# 99
# 92

# %%
''.join(['a', 'b', 'c'])
# Out:
# 'abc'

# %%
[secrets.choice("apple") for _ in range(5)]

''.join(secrets.choice("apple") for _ in range(5))
# Out:
# ['p', 'e', 'l', 'p', 'p']
# 'leppe'

# %%
def generate_token(length=10):
  chars = string.ascii_letters + string.digits
  return ''.join(secrets.choice(chars) for _ in range(length))


generate_token()
# Out:
# 'hYzVQHoMfq'

# %%
chars = string.ascii_letters + string.digits

''.join([secrets.choice(chars) for _ in range(10)])
# Out:
# 'mER4mOcYnt'

# %%
import base64

# %%
type("hello")
type(b"hello")
# Out:
# str
# bytes

# %%
ord("a")
ord("A")
# Out:
# 97
# 65

# %%
[ord(c) for c in "hello"]
# Out:
# [104, 101, 108, 108, 111]

# %%
print("apple\\orange")
# Out:
# apple\orange

# %%
print(r"C:\Users\k26ra\Downloads\DL")
# Out:
# C:\Users\k26ra\Downloads\DL

# %%
encoded = base64.urlsafe_b64encode(b'hello')
type(encoded)

decoded = base64.urlsafe_b64decode(encoded)
type(decoded)

encoded.decode()
decoded.decode()
# Out:
# bytes
# bytes
# 'aGVsbG8='
# 'hello'

# %%
session_id = 1
token = "abc"

base64.urlsafe_b64encode(bytes(f'{session_id}.{token}', encoding='utf-8')).decode()
# Out:
# 'MS5hYmM='

# %%
import json

# %%
payload = {
    "session_id": 1,
    "token": "abc",
}

json.dumps(payload)
# Out:
# '{"session_id": 1, "token": "abc"}'
